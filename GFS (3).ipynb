# %%
import numpy as np
import pandas as pd
from pandas import Series,DataFrame
from numpy.random import randn
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_style('whitegrid')
# %matplotlib inline

# %%
gfs_df = pd.read_csv("pds.csv")

# %%
gfs_df.head()
# Out:
#          Date UTtime  Temperature  RelativeHumidity  Pressure  Windspeed  \
# 0  19-06-2019  01:00       304.91             39.57    975.11       2.73
# 1  19-06-2019  02:00       305.54             38.34    975.33       2.60
# 2  19-06-2019  03:00       306.17             37.11    975.56       2.46
# 3  19-06-2019  04:00       307.55             33.60    975.67       2.25
# 4  19-06-2019  05:00       308.94             30.09    975.79       2.14
#
#    Winddirection  Rainfall  Snowfall  Snowdepth  Short-wave_irradiation
# 0         200.71       0.0         0          0                 81.4634
# 1         202.04       0.0         0          0                233.3528
# 2         203.51       0.0         0          0                413.5005
# 3         192.07       0.0         0          0                600.8880
# 4         178.88       0.0         0          0                779.7729

# %%
gfs_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 11 columns):
# Date                      96 non-null object
# UTtime                    96 non-null object
# Temperature               96 non-null float64
# RelativeHumidity          96 non-null float64
# Pressure                  96 non-null float64
# Windspeed                 96 non-null float64
# Winddirection             96 non-null float64
# Rainfall                  96 non-null float64
# Snowfall                  96 non-null int64
# Snowdepth                 96 non-null int64
# Short-wave_irradiation    96 non-null float64
# dtypes: float64(7), int64(2), object(2)
# memory usage: 8.3+ KB

# %%
def kel_to_cel(celsius):
    Temperature = celsius
    kel = 273.15
    celsius = celsius -kel
    return celsius

# %%
gfs_df['celsius'] = gfs_df['Temperature'].apply(kel_to_cel)

# %%
gfs_df[0:9]
# Out:
#          Date UTtime  Temperature  RelativeHumidity  Pressure  Windspeed  \
# 0  19-06-2019  01:00       304.91             39.57    975.11       2.73
# 1  19-06-2019  02:00       305.54             38.34    975.33       2.60
# 2  19-06-2019  03:00       306.17             37.11    975.56       2.46
# 3  19-06-2019  04:00       307.55             33.60    975.67       2.25
# 4  19-06-2019  05:00       308.94             30.09    975.79       2.14
# 5  19-06-2019  06:00       310.33             26.58    975.91       2.15
# 6  19-06-2019  07:00       311.15             24.19    974.90       1.95
# 7  19-06-2019  08:00       311.98             21.80    973.90       1.76
# 8  19-06-2019  09:00       312.80             19.41    972.89       1.60
#
#    Winddirection  Rainfall  Snowfall  Snowdepth  Short-wave_irradiation  \
# 0         200.71       0.0         0          0                 81.4634
# 1         202.04       0.0         0          0                233.3528
# ...

# %%
def cel_cat(cate):
    celsius = cate
    if cate <= 35:
        return 'In range (30-35) C'
    elif cate <=40 and cate >=35:
        return 'In range (35-40) C'

# %%
gfs_df['cate'] = gfs_df['celsius'].apply(cel_cat)

# %%
sns.catplot('Rainfall', data=gfs_df,hue='cate', kind="count",aspect=4)

# %%
x = gfs_df['celsius']
y = gfs_df['UTtime']
plt.scatter(x,y)
plt.show
plt.xlabel("Temperature in Celsius")
plt.ylabel("Time")
# Out:
# Text(0, 0.5, 'Time')

# %%
x = gfs_df['Pressure']
y = gfs_df['UTtime']
plt.scatter(x,y)
plt.show
plt.xlabel("Pressure in hpa - at ground level")
plt.ylabel("Time")
# Out:
# Text(0, 0.5, 'Time')

# %%
sns.set(style="darkgrid")

g = sns.scatterplot("Pressure", "Temperature",hue='cate', data=gfs_df)

# %%
sns.set(style="whitegrid")

g = sns.jointplot("celsius", "Windspeed", data=gfs_df, kind="reg",
                  xlim=(0, 60), ylim=(0, 12), color="lime", height=7)

# %%
sns.set(style="whitegrid")

g = sns.jointplot("RelativeHumidity", "Windspeed", data=gfs_df, kind="reg",
                  xlim=(0, 60), ylim=(0, 12),color='aqua', height=7)

# %%
gfs_df.head()
# Out:
#          Date UTtime  Temperature  RelativeHumidity  Pressure  Windspeed  \
# 0  19-06-2019  01:00       304.91             39.57    975.11       2.73
# 1  19-06-2019  02:00       305.54             38.34    975.33       2.60
# 2  19-06-2019  03:00       306.17             37.11    975.56       2.46
# 3  19-06-2019  04:00       307.55             33.60    975.67       2.25
# 4  19-06-2019  05:00       308.94             30.09    975.79       2.14
#
#    Winddirection  Rainfall  Snowfall  Snowdepth  Short-wave_irradiation  \
# 0         200.71       0.0         0          0                 81.4634
# 1         202.04       0.0         0          0                233.3528
# 2         203.51       0.0         0          0                413.5005
# 3         192.07       0.0         0          0                600.8880
# 4         178.88       0.0         0          0                779.7729
#
#    celsius                cate
# 0    31.76  In range (30-35) C
# ...

# %%
sns.set(style="whitegrid")
sns.jointplot('Short-wave_irradiation','Temperature', data=gfs_df, color='aqua',kind='reg',order=4,
             xlim=(100, 1000), ylim=(300, 340), height=7)

# %%
sns.lmplot(x='UTtime', y='Windspeed', hue='cate', data=gfs_df, fit_reg=False,aspect=2,palette ='bright',height =7)

# %%
sns.lmplot(x='UTtime', y='Rainfall', hue='cate', data=gfs_df, fit_reg=False,aspect=2,palette ='bright',height =7)

# %%
sns.lmplot(x='UTtime', y='RelativeHumidity', hue='cate', data=gfs_df, fit_reg=False,aspect=2,palette ='bright',height =7)

# %%
sns.lmplot(x='UTtime', y='Winddirection', hue='cate', data=gfs_df, fit_reg=False,aspect=2,palette ='bright',height =7)

# %%
sns.lmplot(x='Date', y='Temperature', hue='cate', data=gfs_df, fit_reg=False,aspect=2,palette ='bright',height =7)
